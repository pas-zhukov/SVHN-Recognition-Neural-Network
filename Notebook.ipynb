# %% [markdown]
# ### Запустим обучение

# %% [markdown]
# **Для того, чтобы первая ячейка сработала, нужно перезапустить ядро Jupyter Notebook!**
#
# ---
#
# Если мы на новом ядре запустим `import main.py`, все команды из этого файла последовательно выполнятся.
#
# Эта схема используется для того, чтобы не приходилось обучение оборачивать в класс.

# %%
import torch
import main
# Out:
# Using downloaded and verified file: ./data/train_32x32.mat
# Using downloaded and verified file: ./data/test_32x32.mat
# /home/pavel/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:152: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 0 of 20
# Average loss: 1.236617, Train accuracy: 0.608521, Val accuracy: 0.649700
# Epoch 1 of 20
# Average loss: 0.870217, Train accuracy: 0.734669, Val accuracy: 0.773403
# Epoch 2 of 20
# Average loss: 0.747286, Train accuracy: 0.772293, Val accuracy: 0.753002
# Epoch 3 of 20
# Average loss: 0.658417, Train accuracy: 0.801266, Val accuracy: 0.816184
# Epoch 4 of 20
# Average loss: 0.600678, Train accuracy: 0.817715, Val accuracy: 0.806769
# Epoch 5 of 20
# Average loss: 0.544684, Train accuracy: 0.835478, Val accuracy: 0.820415
# Epoch 6 of 20
# Average loss: 0.503493, Train accuracy: 0.848394, Val accuracy: 0.817276
# Epoch 7 of 20
# Average loss: 0.471234, Train accuracy: 0.860014, Val accuracy: 0.840338
# Epoch 8 of 20
# Average loss: 0.438534, Train accuracy: 0.869314, Val accuracy: 0.834266
# Epoch 9 of 20
# Average loss: 0.413484, Train accuracy: 0.877077, Val accuracy: 0.851801
# Epoch 10 of 20
# Average loss: 0.389632, Train accuracy: 0.885455, Val accuracy: 0.845251
# Epoch 11 of 20
# Average loss: 0.370555, Train accuracy: 0.890950, Val accuracy: 0.856578
# Epoch 12 of 20
# Average loss: 0.352716, Train accuracy: 0.897485, Val accuracy: 0.857669
# Epoch 13 of 20
# Average loss: 0.340100, Train accuracy: 0.901785, Val accuracy: 0.868791
# Epoch 14 of 20
# Average loss: 0.323478, Train accuracy: 0.907945, Val accuracy: 0.869678
# Epoch 15 of 20
# Average loss: 0.311684, Train accuracy: 0.912176, Val accuracy: 0.861149
# Epoch 16 of 20
# Average loss: 0.302952, Train accuracy: 0.914429, Val accuracy: 0.870838
# Epoch 17 of 20
# Average loss: 0.292235, Train accuracy: 0.919428, Val accuracy: 0.870497
# Epoch 18 of 20
# Average loss: 0.285954, Train accuracy: 0.921237, Val accuracy: 0.869951
# Epoch 19 of 20
# Average loss: 0.276496, Train accuracy: 0.924564, Val accuracy: 0.873226
# Test accuracy: 0.8575

# %% [markdown]
# ### Нарисуем графики, отображающие величину loss функции и точности во времени (в зависимости от эпохи)
#
# ---

# %%
import matplotlib.pyplot as plt

X = list(range(main.num_epochs))

fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Графики тренировочного процесса')

ax1.plot(X, main.train_history, color='r', label='Training')
ax1.plot(X, main.val_history, color='b', label='Validation')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(X, main.loss_history, color='y', label='Loss Function')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

# %% [markdown]
# ### Сохраним модель в ONNX формате
#
# ---

# %%
torch.onnx.export(main.nn_model, main.x, 'svhn.onnx', input_names=["image"], output_names=["Numbers Probabilities"])
